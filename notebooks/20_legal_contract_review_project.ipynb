# %% [markdown]
# # 第 20 章：法律合同审查项目
#
# 对应新版 `roadmap.md` 主线入口。
#
# **核心问题**：如何把 RAG、LoRA、蒸馏、评测和安全组合成法律合同审查小模型？
#
# **本章关注**：合同风险识别, 法条引用检查, 司法辖区, 法律建议边界, 人工律师复核。
#
# **轻量实验**：构造法律项目输出骨架，并校验必需边界字段。
#
# > 说明：本 notebook 只做最小可运行观察，不做大型训练；如果后续要接入仓库内 API，请先确认 API 已存在。

# %%
output = {
    "jurisdiction": "CN",
    "risk_level": "unknown",
    "risk_points": [],
    "evidence": [
        {
            "source_id": "law-toy",
            "title": "教学示例",
            "effective_date": "unknown",
            "span_id": "s1",
            "support_level": "partial",
        }
    ],
    "revision_suggestion": "请由专业律师结合完整合同审阅。",
    "uncertainty": "教学样例证据不足。",
    "legal_advice_boundary": "仅供信息参考，不构成法律意见",
    "needs_human_review": True,
}

required = {"jurisdiction", "risk_level", "evidence", "legal_advice_boundary", "needs_human_review"}
print(output)
assert required <= set(output)
assert output["needs_human_review"] is True

# %% [markdown]
# ## 学习观察
#
# 运行上面的最小实验后，建议记录三点：
#
# 1. 哪个输入或配置最影响输出？
# 2. 这个 toy 实验和本章核心问题之间的对应关系是什么？
# 3. 如果要进入 `src/` 或真实模型实现，还缺哪些已确认的 API、测试或数据？
#
# 本章验收时优先看能否解释：如何把 RAG、LoRA、蒸馏、评测和安全组合成法律合同审查小模型？
