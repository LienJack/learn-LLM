# %% [markdown]
# # 第 22 章：毕业发布审计
#
# 对应新版 `roadmap.md` 主线入口。
#
# **核心问题**：一个领域小模型能不能发布，应该由什么材料证明？
#
# **本章关注**：eval_report, failure_taxonomy, model_card, data_card, risk_report, release_decision, rollback_playbook。
#
# **轻量实验**：检查发布审计材料是否齐全，并给出 release/no release/internal only 结论。
#
# > 说明：本 notebook 只做最小可运行观察，不做大型训练；如果后续要接入仓库内 API，请先确认 API 已存在。

# %%
release_packet = {
    "eval_report.md": True,
    "failure_taxonomy.md": True,
    "model_card.md": True,
    "data_card.md": True,
    "risk_report.md": True,
    "release_decision.md": False,
    "rollback_playbook.md": True,
}

missing = [name for name, exists in release_packet.items() if not exists]
decision = "no release" if missing else "release"

print("missing:", missing)
print("decision:", decision)
assert decision in {"release", "no release", "internal only"}

# %% [markdown]
# ## 学习观察
#
# 运行上面的最小实验后，建议记录三点：
#
# 1. 哪个输入或配置最影响输出？
# 2. 这个 toy 实验和本章核心问题之间的对应关系是什么？
# 3. 如果要进入 `src/` 或真实模型实现，还缺哪些已确认的 API、测试或数据？
#
# 本章验收时优先看能否解释：一个领域小模型能不能发布，应该由什么材料证明？
