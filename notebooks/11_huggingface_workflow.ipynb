# %% [markdown]
# # 第 11 章：Hugging Face 工作流
#
# 对应新版 `roadmap.md` 主线入口。
#
# **核心问题**：现实中不可能每次从零写模型，如何使用开源模型且不把它当黑盒？
#
# **本章关注**：AutoTokenizer, AutoModelForCausalLM, Trainer/custom loop, generate, save_pretrained。
#
# **轻量实验**：在不下载模型的前提下，建立从自实现组件到 Hugging Face API 的映射表。
#
# > 说明：本 notebook 只做最小可运行观察，不做大型训练；如果后续要接入仓库内 API，请先确认 API 已存在。

# %%
component_map = {
    "tokenizer": "AutoTokenizer.from_pretrained(...)（需联网或本地模型目录）",
    "model": "AutoModelForCausalLM.from_pretrained(...)（需确认模型可用）",
    "train_loop": "Trainer 或 custom loop",
    "generate": "model.generate(...)",
    "checkpoint": "save_pretrained(...) / from_pretrained(...)",
}

for local_part, hf_api in component_map.items():
    print(f"{local_part:12s} -> {hf_api}")

# %% [markdown]
# ## 学习观察
#
# 运行上面的最小实验后，建议记录三点：
#
# 1. 哪个输入或配置最影响输出？
# 2. 这个 toy 实验和本章核心问题之间的对应关系是什么？
# 3. 如果要进入 `src/` 或真实模型实现，还缺哪些已确认的 API、测试或数据？
#
# 本章验收时优先看能否解释：现实中不可能每次从零写模型，如何使用开源模型且不把它当黑盒？
